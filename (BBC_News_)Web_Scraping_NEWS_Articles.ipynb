# %% [markdown]
# <a href="https://colab.research.google.com/github/Nahla-yasmine/Arabic-News-Scraper/blob/main/(BBC_News_)Web_Scraping_NEWS_Articles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # (BBC News )Web Scraping NEWS Articles

# %%
# !pip install requests beautifulsoup4 pandas
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.2.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.25.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in /usr/local/lib/python3.10/dist-packages (4.19.0)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in /usr/local/lib/python3.10/dist-packages (from selenium) (2.0.7)
# Requirement already satisfied: trio~=0.17 in /usr/local/lib/python3.10/dist-packages (from selenium) (0.25.0)
# Requirement already satisfied: trio-websocket~=0.9 in /usr/local/lib/python3.10/dist-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.10/dist-packages (from selenium) (2024.2.2)
# Requirement already satisfied: typing_extensions>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from selenium) (4.11.0)
# Requirement already satisfied: attrs>=23.2.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (23.2.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (3.6)
# Requirement already satisfied: outcome in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: wsproto>=0.14 in /usr/local/lib/python3.10/dist-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %% [markdown]
# ## Economic news (first page)

# %%
import time
import pandas as pd
from selenium import webdriver
from bs4 import BeautifulSoup

def web_driver():
    options = webdriver.ChromeOptions()
    options.add_argument("--verbose")
    options.add_argument('--no-sandbox')
    options.add_argument('--headless')
    options.add_argument('--disable-gpu')
    options.add_argument("--window-size=1920,1200")
    options.add_argument('--disable-dev-shm-usage')
    driver = webdriver.Chrome(options=options)
    return driver

def scrape_bbc_arabic():
    driver = web_driver()
    url = 'https://www.bbc.com/arabic/topics/cqywj97d487t'
    driver.get(url)
    time.sleep(5)  # Wait for the page to load

    soup = BeautifulSoup(driver.page_source, 'html.parser')
    articles = soup.find_all('h2', class_='bbc-ghpu9f e47bds20')

    data = []
    for article in articles:
        title = article.text.strip()
        link = article.find('a')['href']
        driver.get(link)  # Visit the article page to extract text
        time.sleep(2)  # Wait for the article page to load
        article_soup = BeautifulSoup(driver.page_source, 'html.parser')
        date_element = article_soup.find('time', class_='bbc-1eu2r82 e1mklfmt0')
        date = date_element.text.strip() if date_element else 'Date not found'
        text_paragraphs = article_soup.find_all('p', class_='bbc-1gjryo4 e17g058b0')
        text = ' '.join([p.text.strip() for p in text_paragraphs])
        data.append({'Title': title, 'Link': link, 'Date': date, 'Text': text})

    driver.quit()
    df = pd.DataFrame(data)
    return df

if __name__ == "__main__":
    df = scrape_bbc_arabic()

# %%
df
# Out:
#                                                 Title  \
# 0   فيديو, باندا و"الورواري".. بائعا فواكه يحرجان ...
# 1   ما أسباب ارتفاع معدل الانتحار بين الشباب الأمر...
# 2   ماذا نعرف عن المليارديرة الفيتنامية التي حكم ع...
# 3   هل سيصبح 75 عاما سن التقاعد، وهل بات ذلك مستحي...
# 4      ماكدونالدز تسترد ملكية فروع مطاعمها في إسرائيل
# 5              خمسة أسئلة حول ما يحدث للاقتصاد الصيني
# 6          كيف تُصدّر أوكرانيا حبوبها وما حجمها الآن؟
# 7   شركة يابانية توقف إنتاج حفاضات الأطفال لتوفيره...
# 8   فيديو, كيف انهار جسر بالتيمور بعد أن اصطدمت به...
# 9   فيديو, شاهد لحظة انهيار جسر بالتيمور في ولاية ...
# 10  فيديو, أسعار الوقود في مصر.. الحكومة ترفعها وا...
# 11  بريطانيا تشهد أكبر ارتفاع في معدل الفقر المدقع...
# 12  عهد جديد للعلاقات بين مصر وأوروبا.. كيف ينعكس ...
# 13  خلل "كارثي" في بنك تجاري سمح للعملاء بسحب ملاي...
# 14   تعرف على رحلة الجنيه المصري من الذهب إلى التعويم
# 15  الأسعار في مصر: ما السبب وراء الارتفاع المستمر...
# 16  الذهب يحقق مكاسب تاريخية.. هل يجب الاستثمار في...
# 17  فيديو, تعويم الجنيه والدولار: سخرية المصريين ف...
# 18  هل يعتبر تعويم الجنيه في مصر حلاً للأزمة المال...
# 19  فيديو, تعويم الجنيه واتفاق صندوق النقد: كيف تف...
# 20  المحكمة العليا تقضي بعدم جواز قرار منع ترامب م...
# 21  أزمة الدواء في مصر: بين تضاعف الأسعار والاختفا...
# 22  عصر "الإقطاع التكنولوجي": هل انتهت الرأسمالية ...
# 23  فيديو, ماذا نعرف عن مشروع  رأس جميلة بمصر؟المد...
#
#                                                 Link  \
# 0   https://www.bbc.com/arabic/articles/cmm3779yqq4o
# 1   https://www.bbc.com/arabic/articles/cv2rlg7vzm2o
# 2   https://www.bbc.com/arabic/articles/c0v01zxw0vlo
# 3   https://www.bbc.com/arabic/articles/c4nrg84r2m3o
# 4   https://www.bbc.com/arabic/articles/c517n8dy71po
# 5   https://www.bbc.com/arabic/articles/c4nlyn53yzqo
# 6   https://www.bbc.com/arabic/articles/cjmxgr0djewo
# 7   https://www.bbc.com/arabic/articles/cyxz1995vd2o
# 8   https://www.bbc.com/arabic/articles/cll5dd6lvz4o
# 9   https://www.bbc.com/arabic/articles/cp4lj5l10d8o
# 10  https://www.bbc.com/arabic/articles/cq5vqvqqdvgo
# 11  https://www.bbc.com/arabic/articles/cy7z5rwp71zo
# 12  https://www.bbc.com/arabic/articles/cn0dq300rzvo
# 13  https://www.bbc.com/arabic/articles/cd192j07q33o
# 14  https://www.bbc.com/arabic/articles/clwejv2yx08o
# 15  https://www.bbc.com/arabic/articles/c72dz6kex03o
# 16  https://www.bbc.com/arabic/articles/cv2y1nw5kdzo
# 17  https://www.bbc.com/arabic/articles/c4nrzv5eyl3o
# 18  https://www.bbc.com/arabic/articles/c2v9ez1g3qdo
# 19  https://www.bbc.com/arabic/articles/crg9nxejnj8o
# 20  https://www.bbc.com/arabic/articles/c2ej5l8ppm8o
# 21  https://www.bbc.com/arabic/articles/c517w7ql42no
# 22  https://www.bbc.com/arabic/articles/cz4z3nxd3wlo
# 23  https://www.bbc.com/arabic/articles/cekez4354ezo
#
#                                Date  \
# 0                    Date not found
# 1                        قبل 7 ساعة
# 2   12 أبريل/ نيسان 2024، 09:20 GMT
# 3              10 أبريل/ نيسان 2024
# 4               5 أبريل/ نيسان 2024
# 5               1 أبريل/ نيسان 2024
# 6                30 مارس/ آذار 2024
# 7                27 مارس/ آذار 2024
# 8                    Date not found
# 9                    Date not found
# 10                   Date not found
# 11               22 مارس/ آذار 2024
# 12               19 مارس/ آذار 2024
# 13               19 مارس/ آذار 2024
# 14               16 مارس/ آذار 2024
# 15               11 مارس/ آذار 2024
# 16                9 مارس/ آذار 2024
# 17                   Date not found
# 18                6 مارس/ آذار 2024
# 19                   Date not found
# 20                5 مارس/ آذار 2024
# 21                4 مارس/ آذار 2024
# 22                2 مارس/ آذار 2024
# 23                   Date not found
#
#                                                  Text
# 0
# 1   ** تحذير: يحتوي المقال على قصص وحقائق قد يجدها...
# 2   تعد محاكمة خضعت لها مليارديرة فيتنامية، الأكثر...
# 3   بات الناس يعيشون عمرا أطول، والحياة أصبحت تزدا...
# 4   تعتزم شركة ماكدونالدز العملاقة للوجبات السريعة...
# 5   يان تشن بي بي سي الصينية منذ أن بدأت الصين في ...
# 6   تصدّر أوكرانيا الآن نحو خمسة ملايين طن من الحب...
# 7   أعلنت شركة يابانية لصناعة الحفاضات أنها ستتوقف...
# 8
# 9
# 10
# 11  أظهرت إحصائيات جديدة أن أزمة أسعار الطاقة تسبب...
# 12  "لا توجد شروط واضحة حول ملف حقوق الإنسان ولا م...
# 13  يسعى أكبر بنك تجاري في إثيوبيا جاهدا لاسترداد ...
# 14  وليد بدران بي بي سي كيف اختفى بريق الجنيه المص...
# 15  عندما يذهب المصريون للتبضع لا يمكنهم معرفة الس...
# 16  ارتفعت أسعار الذهب إلى مستوى تاريخي هذا الأسبو...
# 17
# 18  "أنا كمواطن لا أستطيع أن أعيش" هكذا يشعر الشاب...
# 19
# 20  أبطلت المحكمة العليا الأمريكية الجهود التي بذل...
# 21  أمضي عمرو عبد المجيد (اسم مستعار) نهار يومه، ف...
# 22  تخيّل المشهد التالي: أنت تسير مبتهجاً في مدينة...
# 23

# %% [markdown]
# ## Economic', 'Sport','Science and Technology' News

# %%
import time
import pandas as pd
from selenium import webdriver
from bs4 import BeautifulSoup

def web_driver():
    options = webdriver.ChromeOptions()
    options.add_argument("--verbose")
    options.add_argument('--no-sandbox')
    options.add_argument('--headless')
    options.add_argument('--disable-gpu')
    options.add_argument("--window-size=1920,1200")
    options.add_argument('--disable-dev-shm-usage')
    driver = webdriver.Chrome(options=options)
    return driver

def scrape_bbc_arabic(categories, num_pages=3):
    driver = web_driver()
    data = []

    for category_url, category in categories.items():
        base_url = f'{category_url}?page='

        for page in range(1, num_pages + 1):
            url = base_url + str(page)
            driver.get(url)
            time.sleep(5)  # Wait for the page to load

            soup = BeautifulSoup(driver.page_source, 'html.parser')
            articles = soup.find_all('h2', class_='bbc-ghpu9f e47bds20')

            for article in articles:
                title = article.text.strip()
                link = article.find('a')['href']
                driver.get(link)  # Visit the article page to extract text
                time.sleep(2)  # Wait for the article page to load
                article_soup = BeautifulSoup(driver.page_source, 'html.parser')
                date_element = article_soup.find('time', class_='bbc-1eu2r82 e1mklfmt0')
                date = date_element.text.strip() if date_element else 'Date not found'
                text_paragraphs = article_soup.find_all('p', class_='bbc-1gjryo4 e17g058b0')
                text = ' '.join([p.text.strip() for p in text_paragraphs])
                data.append({'Category': category, 'Title': title, 'Link': link, 'Date': date, 'Text': text})

    driver.quit()
    df = pd.DataFrame(data)
    return df

if __name__ == "__main__":
    categories = {
        'https://www.bbc.com/arabic/topics/cqywj97d487t': 'Economic'

    }
    df_Economic = scrape_bbc_arabic(categories, num_pages=35)  # Change the number of pages as needed

# %%
df_Economic
# Out:
#      Category                                              Title  \
# 0    Economic  فيديو, باندا و"الورواري".. بائعا فواكه يحرجان ...
# 1    Economic  ما أسباب ارتفاع معدل الانتحار بين الشباب الأمر...
# 2    Economic  ماذا نعرف عن المليارديرة الفيتنامية التي حكم ع...
# 3    Economic  هل سيصبح 75 عاما سن التقاعد، وهل بات ذلك مستحي...
# 4    Economic     ماكدونالدز تسترد ملكية فروع مطاعمها في إسرائيل
# ..        ...                                                ...
# 835  Economic  فيديو, كيف سببت أمريكا "انهيار" العملة الإيران...
# 836  Economic  فيديو, عرائس من إيطاليا يتظاهرن من أجل حفلات ا...
# 837  Economic  فيديو, "مضطرون للهجرة إذا أردنا تربية أولادنا"...
# 838  Economic     أوكسفام تنذر بمجاعة عالمية تشمل ثلاث دول عربية
# 839  Economic  أنا مش كافر: كتبها لبناني ثم انتحر ... فما القصة؟
#
#                                                  Link  \
# 0    https://www.bbc.com/arabic/articles/cmm3779yqq4o
# 1    https://www.bbc.com/arabic/articles/cv2rlg7vzm2o
# 2    https://www.bbc.com/arabic/articles/c0v01zxw0vlo
# 3    https://www.bbc.com/arabic/articles/c4nrg84r2m3o
# 4    https://www.bbc.com/arabic/articles/c517n8dy71po
# ..                                                ...
# 835         https://www.bbc.com/arabic/media-53369124
# 836  https://www.bbc.com/arabic/tv-and-radio-53366567
# 837         https://www.bbc.com/arabic/media-53352252
# 838         https://www.bbc.com/arabic/world-53348559
# 839      https://www.bbc.com/arabic/trending-53292695
#
#                                 Date  \
# 0                     Date not found
# 1                         قبل 7 ساعة
# 2    12 أبريل/ نيسان 2024، 09:20 GMT
# 3               10 أبريل/ نيسان 2024
# 4                5 أبريل/ نيسان 2024
# ..                               ...
# 835              10 يوليو/ تموز 2020
# 836              10 يوليو/ تموز 2020
# 837               9 يوليو/ تموز 2020
# 838               9 يوليو/ تموز 2020
# 839               4 يوليو/ تموز 2020
#
#                                                   Text
# 0
# 1    ** تحذير: يحتوي المقال على قصص وحقائق قد يجدها...
# 2    تعد محاكمة خضعت لها مليارديرة فيتنامية، الأكثر...
# 3    بات الناس يعيشون عمرا أطول، والحياة أصبحت تزدا...
# 4    تعتزم شركة ماكدونالدز العملاقة للوجبات السريعة...
# ..                                                 ...
# 835  يواصل الريال الإيراني هبوطه التاريخي في مقابل ...
# 836  عدد من العرائس في إيطاليا يتظاهرن ضد عدم السما...
# 837  في ظل الأزمة الاقتصادية الهائلة التي يمر بها ل...
# 838  حذرت منظمة أوكسفام الخيرية من أن وباء كوفيد-19...
# 839  استيقظ اللبنانيون على فاجعة هزت الرأي العام ال...
#
# [840 rows x 5 columns]

# %%
import time
import pandas as pd
from selenium import webdriver
from bs4 import BeautifulSoup

def web_driver():
    options = webdriver.ChromeOptions()
    options.add_argument("--verbose")
    options.add_argument('--no-sandbox')
    options.add_argument('--headless')
    options.add_argument('--disable-gpu')
    options.add_argument("--window-size=1920,1200")
    options.add_argument('--disable-dev-shm-usage')
    driver = webdriver.Chrome(options=options)
    return driver

def scrape_bbc_arabic(categories, num_pages=3):
    driver = web_driver()
    data = []

    for category_url, category in categories.items():
        base_url = f'{category_url}?page='

        for page in range(1, num_pages + 1):
            url = base_url + str(page)
            driver.get(url)
            time.sleep(5)  # Wait for the page to load

            soup = BeautifulSoup(driver.page_source, 'html.parser')
            articles = soup.find_all('h2', class_='bbc-ghpu9f e47bds20')

            for article in articles:
                title = article.text.strip()
                link = article.find('a')['href']
                driver.get(link)  # Visit the article page to extract text
                time.sleep(2)  # Wait for the article page to load
                article_soup = BeautifulSoup(driver.page_source, 'html.parser')
                date_element = article_soup.find('time', class_='bbc-1eu2r82 e1mklfmt0')
                date = date_element.text.strip() if date_element else 'Date not found'
                text_paragraphs = article_soup.find_all('p', class_='bbc-1gjryo4 e17g058b0')
                text = ' '.join([p.text.strip() for p in text_paragraphs])
                data.append({'Category': category, 'Title': title, 'Link': link, 'Date': date, 'Text': text})

    driver.quit()
    df = pd.DataFrame(data)
    return df

if __name__ == "__main__":
    categories = {
       'https://www.bbc.com/arabic/topics/cyx5kw7g1j2t': 'Sport'
        }
    df_Sport = scrape_bbc_arabic(categories, num_pages=35)  # Change the number of pages as needed

# %%
df_Sport
# Out:
#     Category                                              Title  \
# 0      Sport  فيديو, مشجع سعودي يضرب لاعبا مغربيا بالسوطالمد...
# 1      Sport  فيديو, دوري أبطال أوروبا:  قمة الإثارة في مواج...
# 2      Sport  رونالدو يثير الجدل مجدداً في السعودية بعد ضربه...
# 3      Sport  دوري أبطال أوروبا: الريال يتعادل مع السيتي في ...
# 4      Sport  فيديو, النصر والهلال.. طرد رونالدو لضربه البلي...
# ..       ...                                                ...
# 834    Sport  انتقاد لليويفا بسبب الأماكن المخصصة لمستخدمي ا...
# 835    Sport  كلوب: مباراة نهائي أبطال أوروبا أمام ريال مدري...
# 836    Sport  إصابات وأعمال شغب وترحيل مشجعين بعد اشتباكات ب...
# 837    Sport       الحكومة البريطانية توافق على بيع نادي تشيلسي
# 838    Sport  بي بي سي تعتذر بعد ظهور عبارة "مانشستر يونايتد...
#
#                                                   Link                  Date  \
# 0     https://www.bbc.com/arabic/articles/cpdgzzyvrljo        Date not found
# 1     https://www.bbc.com/arabic/articles/cge8y4lyxn5o        Date not found
# 2     https://www.bbc.com/arabic/articles/cp6gn24k5nro  10 أبريل/ نيسان 2024
# 3     https://www.bbc.com/arabic/articles/ck7l2zyyrwyo   9 أبريل/ نيسان 2024
# 4     https://www.bbc.com/arabic/articles/c3g8kzzdem9o        Date not found
# ..                                                 ...                   ...
# 834         https://www.bbc.com/arabic/sports-61596363    26 مايو/ أيار 2022
# 835         https://www.bbc.com/arabic/sports-61587344    25 مايو/ أيار 2022
# 836         https://www.bbc.com/arabic/sports-61577739    25 مايو/ أيار 2022
# 837         https://www.bbc.com/arabic/sports-61574231    24 مايو/ أيار 2022
# 838  https://www.bbc.com/arabic/art-and-culture-615...    24 مايو/ أيار 2022
#
#                                                   Text
# 0
# 1
# 2    أثار قائد نادي النصر السعودي النجم البرتغالي ك...
# 3    حسم التعادل قمة ريال مدريد الإسباني و ضيفه مان...
# 4
# ..                                                 ...
# 834  قالت رابطة مشجعي نادي ليفربول من ذوي الإعاقة إ...
# 835  يرى مدرب فريق ليفربول الإنجليزي، يورغن كلوب، أ...
# 836  أصيب 19 ضابط شرطة أثناء فض الاشتباكات بين مشجع...
# 837  وافقت الحكومة البريطانية على انتقال ملكية نادي...
# 838  قدمت بي بي سي اعتذارا بعد ظهور رسالة على القنا...
#
# [839 rows x 5 columns]

# %%
import time
import pandas as pd
from selenium import webdriver
from bs4 import BeautifulSoup

def web_driver():
    options = webdriver.ChromeOptions()
    options.add_argument("--verbose")
    options.add_argument('--no-sandbox')
    options.add_argument('--headless')
    options.add_argument('--disable-gpu')
    options.add_argument("--window-size=1920,1200")
    options.add_argument('--disable-dev-shm-usage')
    driver = webdriver.Chrome(options=options)
    return driver

def scrape_bbc_arabic(categories, num_pages=3):
    driver = web_driver()
    data = []

    for category_url, category in categories.items():
        base_url = f'{category_url}?page='

        for page in range(1, num_pages + 1):
            url = base_url + str(page)
            driver.get(url)
            time.sleep(5)  # Wait for the page to load

            soup = BeautifulSoup(driver.page_source, 'html.parser')
            articles = soup.find_all('h2', class_='bbc-ghpu9f e47bds20')

            for article in articles:
                title = article.text.strip()
                link = article.find('a')['href']
                driver.get(link)  # Visit the article page to extract text
                time.sleep(2)  # Wait for the article page to load
                article_soup = BeautifulSoup(driver.page_source, 'html.parser')
                date_element = article_soup.find('time', class_='bbc-1eu2r82 e1mklfmt0')
                date = date_element.text.strip() if date_element else 'Date not found'
                text_paragraphs = article_soup.find_all('p', class_='bbc-1gjryo4 e17g058b0')
                text = ' '.join([p.text.strip() for p in text_paragraphs])
                data.append({'Category': category, 'Title': title, 'Link': link, 'Date': date, 'Text': text})

    driver.quit()
    df = pd.DataFrame(data)
    return df

if __name__ == "__main__":
    categories = {
                'https://www.bbc.com/arabic/topics/clmj3d7282gt': 'Science and Technology'
    }
    df_Science = scrape_bbc_arabic(categories, num_pages=35)  # Change the number of pages as needed

# %%
df_Science
# Out:
#                    Category  \
# 0    Science and Technology
# 1    Science and Technology
# 2    Science and Technology
# 3    Science and Technology
# 4    Science and Technology
# ..                      ...
# 835  Science and Technology
# 836  Science and Technology
# 837  Science and Technology
# 838  Science and Technology
# 839  Science and Technology
#
#                                                  Title  \
# 0    ما أسباب ارتفاع معدل الانتحار بين الشباب الأمر...
# 1      كيف تصل هذه "الكيماويات الضارة" إلى مياه الشرب؟
# 2    لماذا قد يكون من الصعب العثور على الحب في زمن ...
# 3    "هل يمكن اتهام حلفاء إسرائيل بارتكاب جرائم حرب...
# 4    هل صرنا معرّضين للإصابة بالسرطان في سنّ مبكرة؟...
# ..                                                 ...
# 835  توفير اتصال لهواتف أندرويد عبر الأقمار الاصطنا...
# 836  لماذا يتعمد بعض الشباب في الصين التعرض للإصابة...
# 837  كيف تحول أغنى شخص بالعالم إلى أكثر إنسان يفقد ...
# 838  مطالبات بفرض اختبارات كورونا على القادمين من ا...
# 839             مكافحة التنمر على الطريقة الاسكندنافية
#
#                                                   Link  \
# 0     https://www.bbc.com/arabic/articles/cv2rlg7vzm2o
# 1     https://www.bbc.com/arabic/articles/c296pn0gl34o
# 2     https://www.bbc.com/arabic/articles/ce7rdg8er0zo
# 3     https://www.bbc.com/arabic/articles/c80zrggz84eo
# 4     https://www.bbc.com/arabic/articles/cy7zzd5rqqeo
# ..                                                 ...
# 835  https://www.bbc.com/arabic/science-and-tech-64...
# 836          https://www.bbc.com/arabic/world-64187460
# 837       https://www.bbc.com/arabic/business-64173975
# 838  https://www.bbc.com/arabic/science-and-tech-64...
# 839       https://www.bbc.com/arabic/magazine-64167592
#
#                            Date  \
# 0                    قبل 9 ساعة
# 1          11 أبريل/ نيسان 2024
# 2          11 أبريل/ نيسان 2024
# 3          10 أبريل/ نيسان 2024
# 4          10 أبريل/ نيسان 2024
# ..                          ...
# 835  6 يناير/ كانون الثاني 2023
# 836  6 يناير/ كانون الثاني 2023
# 837  5 يناير/ كانون الثاني 2023
# 838  5 يناير/ كانون الثاني 2023
# 839  5 يناير/ كانون الثاني 2023
#
#                                                   Text
# 0    ** تحذير: يحتوي المقال على قصص وحقائق قد يجدها...
# 1    إنها توجد في المياه التي نشربها، وفي أغلفة الأ...
# 2    يقول بول سي برونسون، الباحث الرئيسي في تطبيق T...
# 3    نبدأ جولتنا في عرض الصحف من مجلة التايم الأمري...
# 4    شكل إعلان الأميرة كيت ميدلتون عن إصابتها بالسر...
# ..                                                 ...
# 835  ستوفر شراكة جديدة بين شركة هاتف الأقمار الاصطن...
# 836  عندما أصيب والد السيد تشين، البالغ من العمر 85...
# 837  فقد إيلون ماسك الرئيس التنفيذي لتسلا 200 مليار...
# 838  شدد مسؤولون في الاتحاد الأوروبي على أهمية فرض ...
# 839  ليدي غاغا، شون مينديز، بليك لايفلي، كارين إلسو...
#
# [840 rows x 5 columns]

# %%
import pandas as pd

# Assuming you have three dataframes named df_Science, df_Sport, and df_Economic

# Concatenate the dataframes along the rows
df_merged = pd.concat([df_Science, df_Sport, df_Economic], ignore_index=True)

# Optionally, you can reset the index of the merged dataframe
df_merged.reset_index(drop=True, inplace=True)

summary_stats = df_merged.describe()
print(summary_stats)
# Out:
#                       Category  \
# count                     2519
# unique                       3
# top     Science and Technology
# freq                       840
#
#                                                     Title  \
# count                                                2519
# unique                                               2473
# top     ما أسباب ارتفاع معدل الانتحار بين الشباب الأمر...
# freq                                                    2
#
#                                                     Link            Date  Text
# count                                               2519            2519  2519
# unique                                              2474             886  2390
# top     https://www.bbc.com/arabic/articles/cv2rlg7vzm2o  Date not found
# freq                                                   2              79    84

# %%
df_merged
# Out:
#                     Category  \
# 0     Science and Technology
# 1     Science and Technology
# 2     Science and Technology
# 3     Science and Technology
# 4     Science and Technology
# ...                      ...
# 2514                Economic
# 2515                Economic
# 2516                Economic
# 2517                Economic
# 2518                Economic
#
#                                                   Title  \
# 0     ما أسباب ارتفاع معدل الانتحار بين الشباب الأمر...
# 1       كيف تصل هذه "الكيماويات الضارة" إلى مياه الشرب؟
# 2     لماذا قد يكون من الصعب العثور على الحب في زمن ...
# 3     "هل يمكن اتهام حلفاء إسرائيل بارتكاب جرائم حرب...
# 4     هل صرنا معرّضين للإصابة بالسرطان في سنّ مبكرة؟...
# ...                                                 ...
# 2514  فيديو, كيف سببت أمريكا "انهيار" العملة الإيران...
# 2515  فيديو, عرائس من إيطاليا يتظاهرن من أجل حفلات ا...
# 2516  فيديو, "مضطرون للهجرة إذا أردنا تربية أولادنا"...
# 2517     أوكسفام تنذر بمجاعة عالمية تشمل ثلاث دول عربية
# 2518  أنا مش كافر: كتبها لبناني ثم انتحر ... فما القصة؟
#
#                                                   Link                  Date  \
# 0     https://www.bbc.com/arabic/articles/cv2rlg7vzm2o            قبل 9 ساعة
# 1     https://www.bbc.com/arabic/articles/c296pn0gl34o  11 أبريل/ نيسان 2024
# 2     https://www.bbc.com/arabic/articles/ce7rdg8er0zo  11 أبريل/ نيسان 2024
# 3     https://www.bbc.com/arabic/articles/c80zrggz84eo  10 أبريل/ نيسان 2024
# 4     https://www.bbc.com/arabic/articles/cy7zzd5rqqeo  10 أبريل/ نيسان 2024
# ...                                                ...                   ...
# 2514         https://www.bbc.com/arabic/media-53369124   10 يوليو/ تموز 2020
# 2515  https://www.bbc.com/arabic/tv-and-radio-53366567   10 يوليو/ تموز 2020
# 2516         https://www.bbc.com/arabic/media-53352252    9 يوليو/ تموز 2020
# 2517         https://www.bbc.com/arabic/world-53348559    9 يوليو/ تموز 2020
# 2518      https://www.bbc.com/arabic/trending-53292695    4 يوليو/ تموز 2020
#
#                                                    Text
# 0     ** تحذير: يحتوي المقال على قصص وحقائق قد يجدها...
# 1     إنها توجد في المياه التي نشربها، وفي أغلفة الأ...
# 2     يقول بول سي برونسون، الباحث الرئيسي في تطبيق T...
# 3     نبدأ جولتنا في عرض الصحف من مجلة التايم الأمري...
# 4     شكل إعلان الأميرة كيت ميدلتون عن إصابتها بالسر...
# ...                                                 ...
# 2514  يواصل الريال الإيراني هبوطه التاريخي في مقابل ...
# 2515  عدد من العرائس في إيطاليا يتظاهرن ضد عدم السما...
# 2516  في ظل الأزمة الاقتصادية الهائلة التي يمر بها ل...
# 2517  حذرت منظمة أوكسفام الخيرية من أن وباء كوفيد-19...
# 2518  استيقظ اللبنانيون على فاجعة هزت الرأي العام ال...
#
# [2519 rows x 5 columns]

# %% [markdown]
# **delete out rows where date is 'Date not found' and text is empty**

# %%
# Filter out rows where date is 'Date not found' and text is empty
df_merged = df_merged[(df_merged['Date'] != 'Date not found') & (df_merged['Text'] != '')]

# Reset the index after filtering
df_merged.reset_index(drop=True, inplace=True)

# %%
df_merged
# Out:
#                     Category  \
# 0     Science and Technology
# 1     Science and Technology
# 2     Science and Technology
# 3     Science and Technology
# 4     Science and Technology
# ...                      ...
# 2430                Economic
# 2431                Economic
# 2432                Economic
# 2433                Economic
# 2434                Economic
#
#                                                   Title  \
# 0     ما أسباب ارتفاع معدل الانتحار بين الشباب الأمر...
# 1       كيف تصل هذه "الكيماويات الضارة" إلى مياه الشرب؟
# 2     لماذا قد يكون من الصعب العثور على الحب في زمن ...
# 3     "هل يمكن اتهام حلفاء إسرائيل بارتكاب جرائم حرب...
# 4     هل صرنا معرّضين للإصابة بالسرطان في سنّ مبكرة؟...
# ...                                                 ...
# 2430  فيديو, كيف سببت أمريكا "انهيار" العملة الإيران...
# 2431  فيديو, عرائس من إيطاليا يتظاهرن من أجل حفلات ا...
# 2432  فيديو, "مضطرون للهجرة إذا أردنا تربية أولادنا"...
# 2433     أوكسفام تنذر بمجاعة عالمية تشمل ثلاث دول عربية
# 2434  أنا مش كافر: كتبها لبناني ثم انتحر ... فما القصة؟
#
#                                                   Link                  Date  \
# 0     https://www.bbc.com/arabic/articles/cv2rlg7vzm2o            قبل 9 ساعة
# 1     https://www.bbc.com/arabic/articles/c296pn0gl34o  11 أبريل/ نيسان 2024
# 2     https://www.bbc.com/arabic/articles/ce7rdg8er0zo  11 أبريل/ نيسان 2024
# 3     https://www.bbc.com/arabic/articles/c80zrggz84eo  10 أبريل/ نيسان 2024
# 4     https://www.bbc.com/arabic/articles/cy7zzd5rqqeo  10 أبريل/ نيسان 2024
# ...                                                ...                   ...
# 2430         https://www.bbc.com/arabic/media-53369124   10 يوليو/ تموز 2020
# 2431  https://www.bbc.com/arabic/tv-and-radio-53366567   10 يوليو/ تموز 2020
# 2432         https://www.bbc.com/arabic/media-53352252    9 يوليو/ تموز 2020
# 2433         https://www.bbc.com/arabic/world-53348559    9 يوليو/ تموز 2020
# 2434      https://www.bbc.com/arabic/trending-53292695    4 يوليو/ تموز 2020
#
#                                                    Text
# 0     ** تحذير: يحتوي المقال على قصص وحقائق قد يجدها...
# 1     إنها توجد في المياه التي نشربها، وفي أغلفة الأ...
# 2     يقول بول سي برونسون، الباحث الرئيسي في تطبيق T...
# 3     نبدأ جولتنا في عرض الصحف من مجلة التايم الأمري...
# 4     شكل إعلان الأميرة كيت ميدلتون عن إصابتها بالسر...
# ...                                                 ...
# 2430  يواصل الريال الإيراني هبوطه التاريخي في مقابل ...
# 2431  عدد من العرائس في إيطاليا يتظاهرن ضد عدم السما...
# 2432  في ظل الأزمة الاقتصادية الهائلة التي يمر بها ل...
# 2433  حذرت منظمة أوكسفام الخيرية من أن وباء كوفيد-19...
# 2434  استيقظ اللبنانيون على فاجعة هزت الرأي العام ال...
#
# [2435 rows x 5 columns]

# %% [markdown]
# **Statistics**

# %%
summary_stats = df_merged.describe()
summary_stats
# Out:
#        Category                                              Title  \
# count      2435                                               2435
# unique        3                                               2389
# top       Sport  ما أسباب ارتفاع معدل الانتحار بين الشباب الأمر...
# freq        819                                                  2
#
#                                                     Link  \
# count                                               2435
# unique                                              2390
# top     https://www.bbc.com/arabic/articles/cv2rlg7vzm2o
# freq                                                   2
#
#                                Date  \
# count                          2435
# unique                          884
# top     19 يناير/ كانون الثاني 2023
# freq                             17
#
#                                                      Text
# count                                                2435
# unique                                               2389
# top     ** تحذير: يحتوي المقال على قصص وحقائق قد يجدها...
# freq                                                    2

# %%
# Remove duplicate rows based on the 'Title' column
df_merged_no_duplicates = df_merged.drop_duplicates(subset='Title')

# Reset index after removing duplicates
df_merged_no_duplicates.reset_index(drop=True, inplace=True)

# Print the shape of the dataframe to see how many duplicates were removed
print("Shape of dataframe after removing duplicates:", df_merged_no_duplicates.shape)
# Out:
# Shape of dataframe after removing duplicates: (2389, 5)

# %%
summary_stats = df_merged_no_duplicates.describe()
summary_stats
# Out:
#        Category                                              Title  \
# count      2389                                               2389
# unique        3                                               2389
# top       Sport  ما أسباب ارتفاع معدل الانتحار بين الشباب الأمر...
# freq        809                                                  1
#
#                                                     Link  \
# count                                               2389
# unique                                              2389
# top     https://www.bbc.com/arabic/articles/cv2rlg7vzm2o
# freq                                                   1
#
#                                Date  \
# count                          2389
# unique                          883
# top     19 يناير/ كانون الثاني 2023
# freq                             15
#
#                                                      Text
# count                                                2389
# unique                                               2388
# top     يزور أنيس القديحي معهد علمي في مانشستر للتعرف ...
# freq                                                    2

# %%
df_merged=df_merged_no_duplicates

# %% [markdown]
# **Grouping and Aggregation**

# %%
category_counts = df_merged.groupby('Category').size()
print(category_counts)
# Out:
# Category
# Economic                  780
# Science and Technology    800
# Sport                     809
# dtype: int64

# %%
import matplotlib.pyplot as plt

# Group by category and count the number of articles in each category
category_counts = df_merged.groupby('Category').size()

# Create a bar plot
plt.figure(figsize=(8, 6))
category_counts.plot(kind='bar', color='skyblue')
plt.title('Number of Articles by Category')
plt.xlabel('Category')
plt.ylabel('Count')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %% [markdown]
# **Save the data**

# %%
# Save the merged dataframe to a CSV file
df_merged.to_csv('bbc_arabic_news.csv', index=False)

print("Data has been saved to bbc_arabic_news.csv")
# Out:
# Data has been saved to bbc_arabic_news.csv
